# %%
# load libaries

import pandas as pd
import numpy as np

# %%
# load datasets

df = pd.read_csv("raw/billboard.csv")

# list columns of all three datasets
print("BillBoard Columns: \n", billboard.columns.tolist())
# Out:
# BillBoard Columns:
#  ['date', 'rank', 'song', 'artist', 'last-week', 'peak-rank', 'weeks-on-board']

# %%
print(df)
# Out:
#               date  rank                                 song  \
# 0       2021-11-06     1                           Easy On Me
# 1       2021-11-06     2                                 Stay
# 2       2021-11-06     3                        Industry Baby
# 3       2021-11-06     4                           Fancy Like
# 4       2021-11-06     5                           Bad Habits
# ...            ...   ...                                  ...
# 330082  1958-08-04    96                        Over And Over
# 330083  1958-08-04    97                     I Believe In You
# 330084  1958-08-04    98                      Little Serenade
# 330085  1958-08-04    99  I'll Get By (As Long As I Have You)
# 330086  1958-08-04   100                                 Judy
#
#                                artist  last-week  peak-rank  weeks-on-board
# 0                               Adele        1.0          1               3
# ...

# %%
print(df.dtypes)
# Out:
# date               object
# rank                int64
# song               object
# artist             object
# last-week         float64
# peak-rank           int64
# weeks-on-board      int64
# dtype: object

# %% [markdown]
# ## Convert date to datetime format

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
print(df.dtypes)
# Out:
# date              datetime64[ns]
# rank                       int64
# song                      object
# artist                    object
# last-week                float64
# peak-rank                  int64
# weeks-on-board             int64
# dtype: object

# %% [markdown]
# ## Standardize text formatting (song and artist)

# %%
df["song"] = df["song"].str.strip()
df["artist"] = df["artist"].str.strip()

# %% [markdown]
# ## Check missing value

# %%
df.isnull().sum()
# Out:
# date                  0
# rank                  0
# song                  0
# artist                0
# last-week         32312
# peak-rank             0
# weeks-on-board        0
# dtype: int64

# %%
df = df.dropna()

# %% [markdown]
# ### Include only year 2010 to 2020 sine the research question focues on years between 2010 and 2020

# %%
df_filtered = df[df["date"].dt.year == 2020]

# %%
df_filtered.head()
# Out:
#            date  rank                               song  \
# 4501 2020-12-26     2    All I Want For Christmas Is You
# 4502 2020-12-26     3  Rockin' Around The Christmas Tree
# 4503 2020-12-26     4                   Jingle Bell Rock
# 4504 2020-12-26     5                               Mood
# 4505 2020-12-26     6            A Holly Jolly Christmas
#
#                             artist  last-week  peak-rank  weeks-on-board
# 4501                  Mariah Carey        1.0          1              42
# 4502                    Brenda Lee        3.0          2              37
# 4503                   Bobby Helms        5.0          3              34
# 4504  24kGoldn Featuring iann dior        2.0          1              19
# 4505                     Burl Ives       14.0          4              18

# %%
df_filtered.shape
# Out:
# (4358, 7)

# %%
df_filtered = df_filtered[df_filtered["rank"] <= 50]

# %%
df_filtered.shape
# Out:
# (2329, 7)

# %%
df_filtered = df_filtered.head(2000)

# %%
df_filtered.shape
# Out:
# (2000, 7)

# %%
df_filtered.to_csv("processed/billboard_clean.csv", index=False)
