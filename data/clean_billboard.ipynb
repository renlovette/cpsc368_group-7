# %%
# load libaries

import pandas as pd
import numpy as np

# %%
# load datasets

df = pd.read_csv("raw/billboard.csv")

# list columns of all three datasets
print("BillBoard Columns: \n", df.columns.tolist())
# Out:
# BillBoard Columns:
#  ['date', 'rank', 'song', 'artist', 'last-week', 'peak-rank', 'weeks-on-board']

# %%
print(df)
# Out:
#               date  rank                                 song  \
# 0       2021-11-06     1                           Easy On Me
# 1       2021-11-06     2                                 Stay
# 2       2021-11-06     3                        Industry Baby
# 3       2021-11-06     4                           Fancy Like
# 4       2021-11-06     5                           Bad Habits
# ...            ...   ...                                  ...
# 330082  1958-08-04    96                        Over And Over
# 330083  1958-08-04    97                     I Believe In You
# 330084  1958-08-04    98                      Little Serenade
# 330085  1958-08-04    99  I'll Get By (As Long As I Have You)
# 330086  1958-08-04   100                                 Judy
#
#                                artist  last-week  peak-rank  weeks-on-board
# 0                               Adele        1.0          1               3
# ...

# %%
print(df.dtypes)
# Out:
# date               object
# rank                int64
# song               object
# artist             object
# last-week         float64
# peak-rank           int64
# weeks-on-board      int64
# dtype: object

# %% [markdown]
# ## Convert date to datetime format

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
print(df.dtypes)
# Out:
# date              datetime64[ns]
# rank                       int64
# song                      object
# artist                    object
# last-week                float64
# peak-rank                  int64
# weeks-on-board             int64
# dtype: object

# %% [markdown]
# ## Standardize text formatting (song and artist)

# %%
df["song"] = df["song"].str.strip()
df["artist"] = df["artist"].str.strip()

# %% [markdown]
# ## Check missing value

# %%
df.isnull().sum()
# Out:
# date                  0
# rank                  0
# song                  0
# artist                0
# last-week         32312
# peak-rank             0
# weeks-on-board        0
# dtype: int64

# %%
df = df.dropna()

# %% [markdown]
# ### Include only year 2016 to 2020 since the research question focues on years between 2016 and 2020

# %%
df_filtered = df[(df["date"].dt.year <= 2020)&(df["date"].dt.year >= 2016)]

# %%
billboard_2020 = df_filtered[
    ["date","rank","song","artist","peak-rank","weeks-on-board"]
]

# %%
billboard_2020.shape
# Out:
# (22728, 6)

# %%
billboard_unique = (
    billboard_2020
    .groupby(["song","artist"], as_index=False)
    .agg({
        "peak-rank": "min",
        "weeks-on-board": "max"
    })
)

# %%
billboard_unique.shape
# Out:
# (1804, 4)

# %%
billboard_unique
# Out:
#                                                song  \
# 0                                    $ave Dat Money
# 1     (There's No Place Like) Home For The Holidays
# 2                                  ...Ready For It?
# 3                                           1 Night
# 4                                    1-800-273-8255
# ...                                             ...
# 1799                                           iSpy
# 1800                         idontwannabeyouanymore
# 1801                                            ily
# 1802                                            pov
# 1803                             whoa (mind in awe)
#
#                                                artist  peak-rank  \
# 0     Lil Dicky Featuring Fetty Wap & Rich Homie Quan         71
# 1                                          Perry Como         32
# 2                                        Taylor Swift          4
# 3                                          Lil Yachty         49
# ...

# %%
billboard_unique["song"].value_counts()
# Out:
# song
# X                5
# Roses            3
# Body             3
# The Weekend      2
# Sorry            2
#                 ..
# Growing Pains    1
# Greenlight       1
# Green Light      1
# Greece           1
# Handgun          1
# Name: count, Length: 1748, dtype: int64

# %%
billboard_unique.to_csv("processed/billboard_clean.csv", index=False)
