# %%
# load libaries

import pandas as pd
import numpy as np

# %%
# load datasets

spotify_1 = pd.read_csv("raw/spotify_1.csv")
spotify_2 = pd.read_csv("raw/spotify_2.csv")
spotify_3 = pd.read_csv("raw/spotify_3.csv")

# list columns of all three datasets
print("Spotify 1 Columns: \n", spotify_1.columns.tolist(), "\n Spotify 2 Columns:\n", spotify_2.columns.tolist(), "\n Spotify 3 Columns:\n", spotify_3.columns.tolist())
# Out:
# Spotify 1 Columns:
#  ['id', 'artist_names', 'track_name', 'source', 'key', 'mode', 'time_signature', 'danceability', 'energy', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'loudness', 'tempo', 'duration_ms', 'weeks_on_chart', 'streams']
#  Spotify 2 Columns:
#  ['valence', 'year', 'acousticness', 'artists', 'danceability', 'duration_ms', 'energy', 'explicit', 'id', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'name', 'popularity', 'release_date', 'speechiness', 'tempo']
#  Spotify 3 Columns:
#  ['track_id', 'track_name', 'track_number', 'track_popularity', 'track_duration_ms', 'explicit', 'artist_name', 'artist_popularity', 'artist_followers', 'artist_genres', 'album_id', 'album_name', 'album_release_date', 'album_total_tracks', 'album_type']

# %%
# renaming columns for standardizing
spotify_1 = spotify_1.rename(columns={"id": "track_id"})
spotify_2 = spotify_2.rename(columns={"id": "track_id"})

spotify_1 = spotify_1.rename(columns={"artist_names": "artist_name"})
spotify_2 = spotify_2.rename(columns={"artists": "artist_name"})

spotify_2 = spotify_2.rename(columns={"name": "track_name"})

print(spotify_1.columns, spotify_2.columns, spotify_3.columns)

print(spotify_1.shape, spotify_2.shape, spotify_3.shape)
# Out:
# Index(['track_id', 'artist_name', 'track_name', 'source', 'key', 'mode',
#        'time_signature', 'danceability', 'energy', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'loudness',
#        'tempo', 'duration_ms', 'weeks_on_chart', 'streams'],
#       dtype='object') Index(['valence', 'year', 'acousticness', 'artist_name', 'danceability',
#        'duration_ms', 'energy', 'explicit', 'track_id', 'instrumentalness',
#        'key', 'liveness', 'loudness', 'mode', 'track_name', 'popularity',
#        'release_date', 'speechiness', 'tempo'],
#       dtype='object') Index(['track_id', 'track_name', 'track_number', 'track_popularity',
#        'track_duration_ms', 'explicit', 'artist_name', 'artist_popularity',
#        'artist_followers', 'artist_genres', 'album_id', 'album_name',
#        'album_release_date', 'album_total_tracks', 'album_type'],
#       dtype='object')
# (6513, 19) (170653, 19) (8778, 15)

# %%
# CLEANING: Spotify 1 - Spotify Top Songs And Audio Features

# check data types
print(spotify_1.dtypes)

# check for missing values
missing_values_1 = spotify_1.isnull().sum()
print("Missing values:\n", missing_values_1)

# drop missing values
spotify_1 = spotify_1.dropna()

# check for duplicates
spotify_1 = spotify_1.drop_duplicates()
print("Shapes after dropping duplicates:", spotify_1.shape)

spotify_1.sample(5)
# Out:
# track_id             object
# artist_name          object
# track_name           object
# source               object
# key                  object
# mode                 object
# time_signature       object
# danceability        float64
# energy              float64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# loudness            float64
# tempo               float64
# duration_ms           int64
# weeks_on_chart        int64
# streams               int64
# dtype: object
# Missing values:
#  track_id            0
# artist_name         0
# track_name          0
# source              0
# key                 0
# mode                0
# time_signature      0
# danceability        0
# energy              0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# loudness            0
# tempo               0
# duration_ms         0
# weeks_on_chart      0
# streams             0
# dtype: int64
# Shapes after dropping duplicates: (6513, 19)
#                     track_id                artist_name           track_name  \
# 1291  1ZDmxwg7Lywlx68b7SsJjj                Nicki Minaj             MEGATRON
# 6349  7oDd86yk8itslrA9HRP2ki  The Weeknd, Ariana Grande  Die For You - Remix
# 3628  4MAsYGSgxsaj73dC2lvFC4                      Quavo            WORKIN ME
# 2175  2ZrAjMSmlbDIil0JaVgTHh                 Tory Lanez    Broke In A Minute
# 3716  4RtPruLRZbyirtJGqYHPQm                       Duki    Antes de Perderte
#
#                                                  source    key   mode  \
# 1291                     Young Money/Cash Money Records  C#/Db  Major
# 6349                              XO / Republic Records  C#/Db  Minor
# 3628  Quality Control Music/Motown Records/Capitol R...  G#/Ab  Major
# 2175                                 Interscope Records      C  Minor
# 3716                    DALE PLAY Records / SSJ Records      F  Minor
#
#      time_signature  danceability  energy  speechiness  acousticness  \
# 1291        4 beats         0.893   0.641       0.2720         0.128
# 6349        4 beats         0.531   0.525       0.0671         0.232
# 3628        4 beats         0.792   0.657       0.1910         0.205
# 2175        4 beats         0.929   0.700       0.0906         0.144
# 3716        4 beats         0.812   0.925       0.1130         0.487
#
#       instrumentalness  liveness  valence  loudness    tempo  duration_ms  \
# 1291          0.000081     0.086    0.771    -3.051   94.017       190747
# 6349          0.000000     0.441    0.502    -6.500   66.900       232857
# 3628          0.000004     0.196    0.228    -4.245  169.969       169657
# 2175          0.000000     0.349    0.802    -5.595  120.009       132024
# 3716          0.000000     0.115    0.614    -3.092  110.031       176727
#
#       weeks_on_chart    streams
# 1291               3   17170019
# 6349               2  101104522
# 3628              11   20216082
# 2175               1    5385414
# 3716               1    6108095

# %%
# summary
spotify_1.describe()
# Out:
#        danceability       energy  speechiness  acousticness  instrumentalness  \
# count   6513.000000  6513.000000  6513.000000   6513.000000       6513.000000
# mean       0.681731     0.636522     0.121933      0.236761          0.012469
# std        0.141787     0.164813     0.113441      0.244784          0.075151
# min        0.150000     0.021800     0.023200      0.000008          0.000000
# 25%        0.591000     0.534000     0.044000      0.044400          0.000000
# 50%        0.698000     0.651000     0.072200      0.145000          0.000000
# 75%        0.785000     0.759000     0.163000      0.356000          0.000041
# max        0.985000     0.989000     0.966000      0.994000          0.953000
#
#           liveness      valence     loudness        tempo    duration_ms  \
# count  6513.000000  6513.000000  6513.000000  6513.000000    6513.000000
# mean      0.180168     0.492412    -6.350667   122.117244  202566.684170
# std       0.138054     0.227001     2.536114    29.416097   49199.592333
# min       0.019700     0.032000   -34.475000    46.718000   30133.000000
# 25%       0.097400     0.316000    -7.564000    98.007000  173038.000000
# 50%       0.124000     0.489000    -5.983000   120.034000  198367.000000
# 75%       0.219000     0.669000    -4.673000   142.025000  226003.000000
# max       0.977000     0.982000     1.509000   212.117000  690732.000000
#
#        weeks_on_chart       streams
# count     6513.000000  6.513000e+03
# mean        13.614924  1.089647e+08
# std         24.084051  2.276695e+08
# min          1.000000  2.525159e+06
# 25%          1.000000  8.695060e+06
# 50%          4.000000  2.712856e+07
# 75%         16.000000  9.951456e+07
# max        367.000000  3.528450e+09

# %%
# filter for columns related to research question due to database constraints
cleaned_spotify_1 = spotify_1[["track_id", "instrumentalness" , "danceability", "liveness", "valence", "energy", "acousticness", "tempo", "streams"]]
print(cleaned_spotify_1.shape)
# Out:
# (6513, 9)

# %%
# CLEANING: Spotify 2 - Spotify Dataset 1921-2020 
# check data types
print(spotify_2.dtypes)

# check for missing values
missing_values_2 = spotify_2.isnull().sum()
print("Missing values:\n", missing_values_2)

# drop missing values
spotify_2 = spotify_2.dropna()

# check for duplicates
spotify_2 = spotify_2.drop_duplicates()
print("Shapes after dropping duplicates:", spotify_2.shape)

spotify_2.sample(5)
# Out:
# valence             float64
# year                  int64
# acousticness        float64
# artist_name          object
# danceability        float64
# duration_ms           int64
# energy              float64
# explicit              int64
# track_id             object
# instrumentalness    float64
# key                   int64
# liveness            float64
# loudness            float64
# mode                  int64
# track_name           object
# popularity            int64
# release_date         object
# speechiness         float64
# tempo               float64
# dtype: object
# Missing values:
#  valence             0
# year                0
# acousticness        0
# artist_name         0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# track_id            0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# track_name          0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# dtype: int64
# Shapes after dropping duplicates: (170653, 19)
#         valence  year  acousticness                         artist_name  \
# 21788     0.287  1935        0.5440  ['Sinclair Lewis', 'Frank Arnold']
# 76516     0.710  1936        0.6530                    ['Apocolothoth']
# 32290     0.356  1988        0.0735                       ['Van Halen']
# 131020    0.932  1971        0.3500                    ['Freddie King']
# 57095     0.457  2019        0.6080                    ['XXXTENTACION']
#
#         danceability  duration_ms  energy  explicit                track_id  \
# 21788          0.707       241542   0.218         0  0UWc1zxtt0qUtf6UDHhLyd
# 76516          0.501        77462   0.269         0  6Z4PxDxnJ9XuDE9ZjCUfRJ
# 32290          0.606       271667   0.538         0  2zkZcJD7k5IEAiXop6BUkg
# 131020         0.553       172867   0.638         0  7HIBn41u0vLwDlJKjp8Nmk
# 57095          0.954       120055   0.410         1  0RjJSBBEolCDJ6wDiuVCmh
#
#         instrumentalness  key  liveness  loudness  mode  \
# 21788           0.000000    1    0.2410   -18.886     0
# 76516           0.067900    7    0.4650   -20.111     0
# 32290           0.011400    0    0.0989   -14.982     1
# 131020          0.002680    5    0.0663   -10.595     0
# 57095           0.000018    0    0.1330    -7.725     1
#
#                                         track_name  popularity release_date  \
# 21788   Das ist bei uns nicht möglich, Kapitel 101           0         1935
# 76516                                       Heaven           0   1936-11-15
# 32290                                Feels so Good          41   1988-05-24
# 131020                          Worried Life Blues          27         1971
# 57095                                   ATTENTION!          70   2019-12-06
#
#         speechiness    tempo
# 21788        0.9460  127.828
# 76516        0.3120  173.224
# 32290        0.0360   88.334
# 131020       0.0404  159.186
# 57095        0.1570  130.074

# %%
# summary
spotify_2.describe()
# Out:
#              valence           year   acousticness   danceability  \
# count  170653.000000  170653.000000  170653.000000  170653.000000
# mean        0.528587    1976.787241       0.502115       0.537396
# std         0.263171      25.917853       0.376032       0.176138
# min         0.000000    1921.000000       0.000000       0.000000
# 25%         0.317000    1956.000000       0.102000       0.415000
# 50%         0.540000    1977.000000       0.516000       0.548000
# 75%         0.747000    1999.000000       0.893000       0.668000
# max         1.000000    2020.000000       0.996000       0.988000
#
#         duration_ms         energy       explicit  instrumentalness  \
# count  1.706530e+05  170653.000000  170653.000000     170653.000000
# mean   2.309483e+05       0.482389       0.084575          0.167010
# std    1.261184e+05       0.267646       0.278249          0.313475
# min    5.108000e+03       0.000000       0.000000          0.000000
# 25%    1.698270e+05       0.255000       0.000000          0.000000
# 50%    2.074670e+05       0.471000       0.000000          0.000216
# 75%    2.624000e+05       0.703000       0.000000          0.102000
# max    5.403500e+06       1.000000       1.000000          1.000000
#
#                  key       liveness       loudness           mode  \
# count  170653.000000  170653.000000  170653.000000  170653.000000
# mean        5.199844       0.205839     -11.467990       0.706902
# std         3.515094       0.174805       5.697943       0.455184
# min         0.000000       0.000000     -60.000000       0.000000
# 25%         2.000000       0.098800     -14.615000       0.000000
# 50%         5.000000       0.136000     -10.580000       1.000000
# 75%         8.000000       0.261000      -7.183000       1.000000
# max        11.000000       1.000000       3.855000       1.000000
#
#           popularity    speechiness          tempo
# count  170653.000000  170653.000000  170653.000000
# mean       31.431794       0.098393     116.861590
# std        21.826615       0.162740      30.708533
# min         0.000000       0.000000       0.000000
# 25%        11.000000       0.034900      93.421000
# 50%        33.000000       0.045000     114.729000
# 75%        48.000000       0.075600     135.537000
# max       100.000000       0.970000     243.507000

# %%
# research questions only concerns songs from 2010 onwards, filter for these specific years to meet limit of database
filtered_spotify_2 = spotify_2[spotify_2["year"] >= 2010]

# filter for columns related to research question due to database constraints
cleaned_spotify_2 = filtered_spotify_2[["track_id", "instrumentalness" , "danceability", "liveness", "valence", "energy", "acousticness", "tempo", "year"]]


print(cleaned_spotify_2.shape)
print(cleaned_spotify_2.describe())
# Out:
# (21804, 9)
#        instrumentalness  danceability      liveness       valence  \
# count      21804.000000  21804.000000  21804.000000  21804.000000
# mean           0.080806      0.606309      0.188530      0.460530
# std            0.235061      0.170930      0.153838      0.240829
# min            0.000000      0.000000      0.000000      0.000000
# 25%            0.000000      0.502750      0.097100      0.272000
# 50%            0.000002      0.619000      0.124000      0.447000
# 75%            0.000768      0.732000      0.231000      0.641000
# max            1.000000      0.986000      0.989000      0.993000
#
#              energy  acousticness         tempo          year
# count  21804.000000  21804.000000  21804.000000  21804.000000
# mean       0.629218      0.259982    121.160507   2015.004403
# std        0.219571      0.292144     30.327837      3.181665
# min        0.000020      0.000000      0.000000   2010.000000
# 25%        0.496000      0.024200     97.120500   2012.000000
# 50%        0.657000      0.132000    121.011000   2015.000000
# 75%        0.799000      0.426000    140.266000   2018.000000
# max        1.000000      0.996000    220.099000   2020.000000

# %%
# check overlap between spotify 1 and spotify 2
overlap = cleaned_spotify_1[cleaned_spotify_1['track_id'].isin(cleaned_spotify_2['track_id'])].shape[0]
print(overlap)
# Out:
# 1966

# %%
spotify_audible_features = cleaned_spotify_1.merge(cleaned_spotify_2, on=['track_id'], how='inner')
print(spotify_audible_features.shape)
print(spotify_audible_features.describe())
# Out:
# (1966, 17)
#        instrumentalness_x  danceability_x   liveness_x    valence_x  \
# count         1966.000000     1966.000000  1966.000000  1966.000000
# mean             0.010579        0.694417     0.172366     0.475903
# std              0.065323        0.138298     0.126259     0.220232
# min              0.000000        0.153000     0.021500     0.036300
# 25%              0.000000        0.611250     0.096825     0.304000
# 50%              0.000000        0.710500     0.123000     0.465500
# 75%              0.000022        0.793000     0.204000     0.645000
# max              0.918000        0.980000     0.908000     0.970000
#
#           energy_x  acousticness_x      tempo_x       streams  \
# count  1966.000000     1966.000000  1966.000000  1.966000e+03
# mean      0.621398        0.222124   122.306625  1.515278e+08
# std       0.160899        0.238278    29.964930  2.984120e+08
# min       0.027900        0.000042    54.747000  2.580512e+06
# 25%       0.523000        0.040225    97.028750  1.206419e+07
# 50%       0.632000        0.134000   120.054500  4.199005e+07
# 75%       0.740000        0.323000   143.986750  1.587913e+08
# max       0.972000        0.978000   207.476000  3.528450e+09
#
#        instrumentalness_y  danceability_y   liveness_y    valence_y  \
# count         1966.000000     1966.000000  1966.000000  1966.000000
# mean             0.010604        0.694400     0.172504     0.475846
# std              0.065232        0.138326     0.126197     0.220190
# min              0.000000        0.153000     0.021500     0.036300
# 25%              0.000000        0.611000     0.096950     0.304000
# 50%              0.000000        0.710500     0.123000     0.465500
# 75%              0.000022        0.793000     0.204000     0.645000
# max              0.918000        0.980000     0.908000     0.970000
#
#           energy_y  acousticness_y      tempo_y         year
# count  1966.000000     1966.000000  1966.000000  1966.000000
# mean      0.621499        0.222276   122.291974  2018.252798
# std       0.160882        0.238420    29.971532     1.781065
# min       0.027900        0.000042    54.747000  2010.000000
# 25%       0.523000        0.040200    97.028750  2017.000000
# 50%       0.632000        0.134000   120.054500  2019.000000
# 75%       0.740000        0.323000   143.983000  2020.000000
# max       0.972000        0.978000   207.476000  2020.000000

# %%
# check for missing values
missing_values_1 = spotify_1.isnull().sum()
print("Missing values:\n", missing_values_1)

missing_values_2 = spotify_2.isnull().sum()
print("Missing values:\n", missing_values_2)

missing_values_3 = spotify_3.isnull().sum()
print("Missing values:\n", missing_values_3)
# Out:
# Missing values:
#  track_id            0
# artist_name         0
# track_name          0
# source              0
# key                 0
# mode                0
# time_signature      0
# danceability        0
# energy              0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# loudness            0
# tempo               0
# duration_ms         0
# weeks_on_chart      0
# streams             0
# dtype: int64
# Missing values:
#  valence             0
# year                0
# acousticness        0
# artist_name         0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# track_id            0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# track_name          0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# dtype: int64
# Missing values:
#  track_id              0
# track_name            2
# track_number          0
# track_popularity      0
# track_duration_ms     0
# explicit              0
# artist_name           4
# artist_popularity     4
# artist_followers      4
# artist_genres         4
# album_id              0
# album_name            2
# album_release_date    0
# album_total_tracks    0
# album_type            0
# dtype: int64

# %%
# Drop rows with missing values
spotify_2 = spotify_2.dropna()
print("Shape after dropping missing values:", spotify_2.shape)
# Out:
# Shape after dropping missing values: (170653, 19)

# %%
# Remove duplicates
spotify_1 = spotify_1.drop_duplicates()
spotify_2 = spotify_2.drop_duplicates()
spotify_3 = spotify_3.drop_duplicates()

print("Shapes after dropping duplicates:", spotify_1.shape, spotify_2.shape, spotify_3.shape)
# Out:
# Shapes after dropping duplicates: (6513, 19) (8772, 15) (170653, 19)

# %%
# Check data types
print("\nData types:")
print(spotify_1.dtypes)
print(spotify_2.dtypes)
print(spotify_3.dtypes)
# Out:
# Data types:
# track_id             object
# artist_name          object
# track_name           object
# source               object
# key                  object
# mode                 object
# time_signature       object
# danceability        float64
# energy              float64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# loudness            float64
# tempo               float64
# duration_ms           int64
# weeks_on_chart        int64
# streams               int64
# dtype: object
# track_id               object
# track_name             object
# track_number            int64
# track_popularity        int64
# track_duration_ms       int64
# explicit                 bool
# artist_name            object
# artist_popularity     float64
# artist_followers      float64
# artist_genres          object
# album_id               object
# album_name             object
# album_release_date     object
# album_total_tracks      int64
# album_type             object
# dtype: object
# valence             float64
# year                  int64
# acousticness        float64
# artist_name          object
# danceability        float64
# duration_ms           int64
# energy              float64
# explicit              int64
# track_id             object
# instrumentalness    float64
# key                   int64
# liveness            float64
# loudness            float64
# mode                  int64
# track_name           object
# popularity            int64
# release_date         object
# speechiness         float64
# tempo               float64
# dtype: object

# %%
# check for overlaps in tracks

shared_between_1_2 = spotify_1[spotify_1["track_id"].isin(spotify_2["track_id"])].shape[0]
print(shared_between_1_2, "tracks overlapping in dataset 1 and 2")

shared_between_1_3 = spotify_1[spotify_1["track_id"].isin(spotify_3["track_id"])].shape[0]
print(shared_between_1_3, "tracks overlapping in dataset 1 and 3")

shared_between_2_3 = spotify_2[spotify_2["track_id"].isin(spotify_3["track_id"])].shape[0]
print(shared_between_2_3, "tracks overlapping in dataset 2 and 3")
# Out:
# 1556 tracks overlapping in dataset 1 and 2
# 2090 tracks overlapping in dataset 1 and 3
# 2866 tracks overlapping in dataset 2 and 3

# %%
# merging

spotify_1_2 = spotify_1.merge(spotify_2, on="track_id", how="outer", suffixes=("_1", "_2"))
spotify_1_2_3 = spotify_3.merge(spotify_1_2, on="track_id", how="outer", suffixes=("", "_3"))

print(spotify_1_2_3.shape)
print(spotify_1_2_3.columns)
# Out:
# (180182, 51)
# Index(['valence', 'year', 'acousticness', 'artist_name', 'danceability',
#        'duration_ms', 'energy', 'explicit', 'track_id', 'instrumentalness',
#        'key', 'liveness', 'loudness', 'mode', 'track_name', 'popularity',
#        'release_date', 'speechiness', 'tempo', 'artist_name_1', 'track_name_1',
#        'source', 'key_3', 'mode_3', 'time_signature', 'danceability_3',
#        'energy_3', 'speechiness_3', 'acousticness_3', 'instrumentalness_3',
#        'liveness_3', 'valence_3', 'loudness_3', 'tempo_3', 'duration_ms_3',
#        'weeks_on_chart', 'streams', 'track_name_2', 'track_number',
#        'track_popularity', 'track_duration_ms', 'explicit_3', 'artist_name_2',
#        'artist_popularity', 'artist_followers', 'artist_genres', 'album_id',
#        'album_name', 'album_release_date', 'album_total_tracks', 'album_type'],
#       dtype='object')

# %%
spotify_1_2_3.head()
# Out:
#    valence    year  acousticness            artist_name  danceability  \
# 0    0.555  1978.0        0.0131            ['Blondie']         0.256
# 1    0.146  2008.0        0.4690         ['Atmosphere']         0.797
# 2    0.494  1953.0        0.9800      ['Talat Mahmood']         0.277
# 3    0.854  1954.0        0.7950  ['Meade "Lux" Lewis']         0.685
# 4    0.969  1954.0        0.6560     ['Trio Maravilla']         0.788
#
#    duration_ms  energy  explicit                track_id  instrumentalness  \
# 0     182347.0   0.895       0.0  000G1xMMuwxNHmwVsBdtj1          0.000106
# 1     180160.0   0.898       1.0  000GyYHG4uWmlXieKLij8u          0.000000
# 2     206972.0   0.145       0.0  000Npgk5e2SgwGaIsN3ztv          0.879000
# 3     314667.0   0.483       0.0  000ZxLGm7jDlWCHtcXSeBe          0.878000
# 4     179747.0   0.808       0.0  000jBcNljWTnyjB4YO7ojf          0.000000
#
#    ...  explicit_3  artist_name_2  artist_popularity  artist_followers  \
# 0  ...         NaN            NaN                NaN               NaN
# 1  ...         NaN            NaN                NaN               NaN
# 2  ...         NaN            NaN                NaN               NaN
# 3  ...         NaN            NaN                NaN               NaN
# 4  ...         NaN            NaN                NaN               NaN
#
#   artist_genres  album_id album_name  album_release_date  album_total_tracks  \
# 0           NaN       NaN        NaN                 NaN                 NaN
# 1           NaN       NaN        NaN                 NaN                 NaN
# 2           NaN       NaN        NaN                 NaN                 NaN
# 3           NaN       NaN        NaN                 NaN                 NaN
# 4           NaN       NaN        NaN                 NaN                 NaN
#
#   album_type
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 51 columns]

# %%
merged_missing_values = spotify_1_2_3.isnull().sum()
print("Missing values:\n", merged_missing_values)

cleaned_spotify = spotify_1_2_3.dropna()
print("Shape after dropping missing values:", cleaned_spotify.shape)
# Out:
# Missing values:
#  valence                 9529
# year                    9529
# acousticness            9529
# artist_name             9529
# danceability            9529
# duration_ms             9529
# energy                  9529
# explicit                9529
# track_id                   0
# instrumentalness        9529
# key                     9529
# liveness                9529
# loudness                9529
# mode                    9529
# track_name              9529
# popularity              9529
# release_date            9529
# speechiness             9529
# tempo                   9529
# artist_name_1         173669
# track_name_1          173669
# source                173669
# key_3                 173669
# mode_3                173669
# time_signature        173669
# danceability_3        173669
# energy_3              173669
# speechiness_3         173669
# acousticness_3        173669
# instrumentalness_3    173669
# liveness_3            173669
# valence_3             173669
# loudness_3            173669
# tempo_3               173669
# duration_ms_3         173669
# weeks_on_chart        173669
# streams               173669
# track_name_2          171410
# track_number          171410
# track_popularity      171410
# track_duration_ms     171410
# explicit_3            171410
# artist_name_2         171410
# artist_popularity     171410
# artist_followers      171410
# artist_genres         171410
# album_id              171410
# album_name            171410
# album_release_date    171410
# album_total_tracks    171410
# album_type            171410
# dtype: int64
# Shape after dropping missing values: (756, 51)

# %%
cleaned_spotify.describe()
# Out:
#           valence         year  acousticness  danceability    duration_ms  \
# count  756.000000   756.000000    756.000000    756.000000     756.000000
# mean     0.455300  2016.820106      0.236196      0.674700  210120.789683
# std      0.224503     5.502983      0.253291      0.143851   48536.278363
# min      0.039700  1971.000000      0.000060      0.153000   78681.000000
# 25%      0.279250  2017.000000      0.041650      0.584000  180905.500000
# 50%      0.450500  2018.000000      0.142000      0.688000  205153.000000
# 75%      0.624250  2019.000000      0.347500      0.777250  230848.000000
# max      0.969000  2020.000000      0.978000      0.970000  577199.000000
#
#            energy    explicit  instrumentalness         key    liveness  ...  \
# count  756.000000  756.000000        756.000000  756.000000  756.000000  ...
# mean     0.610644    0.419312          0.012532    5.355820    0.163496  ...
# std      0.167602    0.493773          0.067376    3.683736    0.119851  ...
# min      0.056100    0.000000          0.000000    0.000000    0.021500  ...
# 25%      0.506000    0.000000          0.000000    1.750000    0.093100  ...
# 50%      0.619500    0.000000          0.000000    6.000000    0.117500  ...
# 75%      0.732250    1.000000          0.000036    9.000000    0.193000  ...
# max      0.978000    1.000000          0.832000   11.000000    0.914000  ...
#
#           tempo_3  duration_ms_3  weeks_on_chart       streams  track_number  \
# count  756.000000     756.000000      756.000000  7.560000e+02    756.000000
# mean   119.257775  210120.576720       37.042328  2.922427e+08      5.085979
# std     27.651787   48536.666548       46.935106  4.344776e+08      4.413917
# min     62.446000   78681.000000        1.000000  2.638669e+06      1.000000
# 25%     97.959000  180905.500000        6.000000  3.144473e+07      1.000000
# 50%    117.223500  205153.000000       23.000000  1.240877e+08      4.000000
# 75%    139.922750  230848.000000       50.000000  3.858233e+08      8.000000
# max    207.476000  577199.000000      367.000000  3.528450e+09     24.000000
#
#        track_popularity  track_duration_ms  artist_popularity  \
# count        756.000000         756.000000         756.000000
# mean          68.575397      210122.048942          80.891534
# std           18.883915       48536.094367           9.895688
# min            0.000000       78680.000000          44.000000
# 25%           65.750000      180905.250000          75.000000
# 50%           73.000000      205152.000000          81.000000
# 75%           79.000000      230847.750000          88.000000
# max           92.000000      577199.000000         100.000000
#
#        artist_followers  album_total_tracks
# count      7.560000e+02          756.000000
# mean       4.313656e+07           11.785714
# std        4.309859e+07            7.304474
# min        1.356100e+04            1.000000
# 25%        8.506651e+06            7.000000
# 50%        2.611655e+07           13.000000
# 75%        5.888059e+07           16.000000
# max        1.455421e+08           59.000000
#
# [8 rows x 33 columns]

# %%
cleaned_spotify['is_duplicate'] = cleaned_spotify.duplicated(subset='track_id', keep=False)
print(cleaned_spotify['is_duplicate'].value_counts())
# Out:
# is_duplicate
# False    756
# Name: count, dtype: int64
# /tmp/ipykernel_4466/3792311719.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_spotify['is_duplicate'] = cleaned_spotify.duplicated(subset='track_id', keep=False)

# %%
cleaned_spotify.columns
# Out:
# Index(['valence', 'year', 'acousticness', 'artist_name', 'danceability',
#        'duration_ms', 'energy', 'explicit', 'track_id', 'instrumentalness',
#        'key', 'liveness', 'loudness', 'mode', 'track_name', 'popularity',
#        'release_date', 'speechiness', 'tempo', 'artist_name_1', 'track_name_1',
#        'source', 'key_3', 'mode_3', 'time_signature', 'danceability_3',
#        'energy_3', 'speechiness_3', 'acousticness_3', 'instrumentalness_3',
#        'liveness_3', 'valence_3', 'loudness_3', 'tempo_3', 'duration_ms_3',
#        'weeks_on_chart', 'streams', 'track_name_2', 'track_number',
#        'track_popularity', 'track_duration_ms', 'explicit_3', 'artist_name_2',
#        'artist_popularity', 'artist_followers', 'artist_genres', 'album_id',
#        'album_name', 'album_release_date', 'album_total_tracks', 'album_type',
#        'is_duplicate'],
#       dtype='object')

# %%
cleaned_spotify.head()
# Out:
#       valence    year  acousticness                       artist_name  \
# 21      0.236  2004.0       0.00121                   ['The Killers']
# 65      0.665  2018.0       0.28700  ['Cardi B', 'Chance the Rapper']
# 452     0.467  2020.0       0.16700                      ['Dua Lipa']
# 982     0.531  2020.0       0.44000                 ['Glass Animals']
# 1516    0.195  2017.0       0.11300    ['Lana Del Rey', 'A$AP Rocky']
#
#       danceability  duration_ms  energy  explicit                track_id  \
# 21           0.352     222973.0   0.911       0.0  003vvx7Niy0yvhvHt4a68B
# 65           0.620     284856.0   0.625       1.0  00B7TZ0Xawar6NZ00JFomN
# 452          0.730     221820.0   0.729       0.0  017PF4Q3l4DBUiWoXk4OWT
# 982          0.761     238805.0   0.525       0.0  02MWAaffLxlfxAUY7c5dvx
# 1516         0.359     264038.0   0.600       1.0  03hqMhmCZiNKMSPmVabPLP
#
#       instrumentalness  ...  artist_name_2  artist_popularity  \
# 21            0.000000  ...    The Killers               76.0
# 65            0.000000  ...        Cardi B               81.0
# 452           0.000001  ...       Dua Lipa               85.0
# 982           0.000007  ...  Glass Animals               73.0
# 1516          0.000001  ...   Lana Del Rey               88.0
#
#       artist_followers         artist_genres                album_id  \
# 21           8006321.0  ['alternative rock']  4piJq7R3gjUOxnYs6lDCTg
# 65          25953771.0                    []  4KdtEKjY3Gi0mKiSdy96ML
# 452         46886554.0               ['pop']  7fJJK56U9fHixgO0HQkhtI
# 982          4568462.0                    []  0KTj6k94XZh0c6IEMfxeWV
# 1516        51821190.0                    []  7xYiTrbTL57QO0bb4hXIKo
#
#                       album_name album_release_date  album_total_tracks  \
# 21                      Hot Fuss               2004                12.0
# 65           Invasion of Privacy         2018-04-06                13.0
# 452             Future Nostalgia         2020-03-27                11.0
# 982   Dreamland (+ Bonus Levels)         2020-08-06                18.0
# 1516               Lust For Life         2017-07-21                16.0
#
#       album_type is_duplicate
# 21         album        False
# 65         album        False
# 452        album        False
# 982        album        False
# 1516       album        False
#
# [5 rows x 52 columns]
